# %% [markdown]
# <a href="https://colab.research.google.com/github/YerimLee00/YBIGTA21/blob/main/0809_AWS_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 새로운 인스턴스 (YBIGTA_AWS_server) 생성
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Local에 aws.py 만들기
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. aws.py를 Local에서 ec2(YBIGTA_AWS_server)로 전송
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. aws.py를 ec2(YBIGTA_AWS_server)에서 Local로 다운로드
# ![image.png](data:image/png;base64,...)
